# %%
import pandas as pd
import numpy as np

df = pd.read_csv('HRSA 20202022 5 states.csv')

# %%
# Use the head method to print the first 5 rows of df
df.head()
# Out:
#   Filtered By: State = 'District of Columbia' OR State = 'New Jersey' OR State = 'Puerto Rico' OR State = 'New York' OR State = 'Texas'  \
# 0                                                NaN
# 1                                                NaN
# 2                                   County FIPS Code
# 3                                              11001
# 4                                              34001
#
#     Unnamed: 1            Unnamed: 2            Unnamed: 3  \
# 0          NaN                   NaN                   NaN
# 1          NaN                   NaN                   NaN
# 2  HRSA Region                 State                County
# 3            3  District of Columbia  District of Columbia
# 4            2            New Jersey       Atlantic County
#
#                           Unnamed: 4                          Unnamed: 5  \
# 0                                NaN                                 NaN
# ...

# %%
#remove columns 22 through 31
df = df.drop(df.columns[22:32], axis=1)

# %%
df.head()
# Out:
#   Filtered By: State = 'District of Columbia' OR State = 'New Jersey' OR State = 'Puerto Rico' OR State = 'New York' OR State = 'Texas'  \
# 0                                                NaN
# 1                                                NaN
# 2                                   County FIPS Code
# 3                                              11001
# 4                                              34001
#
#     Unnamed: 1            Unnamed: 2            Unnamed: 3  \
# 0          NaN                   NaN                   NaN
# 1          NaN                   NaN                   NaN
# 2  HRSA Region                 State                County
# 3            3  District of Columbia  District of Columbia
# 4            2            New Jersey       Atlantic County
#
#                           Unnamed: 4                          Unnamed: 5  \
# 0                                NaN                                 NaN
# ...

# %%
#remove colums 14 through 21
df = df.drop(df.columns[14:22], axis=1)

# %%
df.head()
# Out:
#   Filtered By: State = 'District of Columbia' OR State = 'New Jersey' OR State = 'Puerto Rico' OR State = 'New York' OR State = 'Texas'  \
# 0                                                NaN
# 1                                                NaN
# 2                                   County FIPS Code
# 3                                              11001
# 4                                              34001
#
#     Unnamed: 1            Unnamed: 2            Unnamed: 3  \
# 0          NaN                   NaN                   NaN
# 1          NaN                   NaN                   NaN
# 2  HRSA Region                 State                County
# 3            3  District of Columbia  District of Columbia
# 4            2            New Jersey       Atlantic County
#
#                           Unnamed: 4                          Unnamed: 5  \
# 0                                NaN                                 NaN
# ...

# %%
#print rows that have Preterm Births (%) < 10.4
df[df['Preterm Births (%) 2020-2022'] < 10.4]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Mobile Documents/com~apple~CloudDocs/health data/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Preterm Births (%) 2020-2022'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
# ...

# %%
# Remove the first two rows which are not needed
df = df.drop([0, 1])

# Reset the index
df = df.reset_index(drop=True)

# Rename the columns
df.columns = [
    'County FIPS Code', 'HRSA Region', 'State', 'County', 
    'Hospitals with Obstetric Care (#)', 'OB-GYN Provider Rate (per 100,000)', 
    'Infant Mortality Rate (per 1,000) 2020-2022', 'Low Birth Weight (%) 2020-2022', 
    'Preterm Births (%) 2020-2022', 'Prenatal Care in the 1st Trimester (%) 2020-2022', 
    'Population Density - Women 15-44 Years of Age', 'NCHS Urban-Rural Classification', 
    'NCHS Urban-Rural Code', 'Unnamed: 13'
]

# Drop the last column which is not needed
df = df.drop(columns=['Unnamed: 13'])

# Display the cleaned DataFrame
df.head()

# %%
df = df.drop([0, 1])

# Reset the index
df = df.reset_index(drop=True)

# Rename the columns
df.columns = [
    'County FIPS Code', 'HRSA Region', 'State', 'County', 
    'Hospitals with Obstetric Care (#)', 'OB-GYN Provider Rate (per 100,000)', 
    'Infant Mortality Rate (per 1,000) 2020-2022', 'Low Birth Weight (%) 2020-2022', 
    'Preterm Births (%) 2020-2022', 'Prenatal Care in the 1st Trimester (%) 2020-2022', 
    'Population Density - Women 15-44 Years of Age', 'NCHS Urban-Rural Classification', 
    'NCHS Urban-Rural Code', 'Unnamed: 13'
]

# Drop the last column which is not needed
df = df.drop(columns=['Unnamed: 13'])

# Display the cleaned DataFrame
df.head()
# Out:
#    County FIPS Code  HRSA Region                 State                County  \
# 0  County FIPS Code  HRSA Region                 State                County
# 1             11001            3  District of Columbia  District of Columbia
# 2             34001            2            New Jersey       Atlantic County
# 3             34003            2            New Jersey         Bergen County
# 4             34005            2            New Jersey     Burlington County
#
#    Hospitals with Obstetric Care (#)  OB-GYN Provider Rate (per 100,000)  \
# 0  Hospitals with Obstetric Care (#)  OB-GYN Provider Rate (per 100,000)
# 1                                  4                                  60
# 2                                  1                                13.3
# 3                                  5                                48.1
# 4                                  1                                  19
#
#    Infant Mortality Rate (per 1,000) 2020-2022  \
# ...

# %%
# print the number of rows and columns in the dataframe
df.shape
# Out:
# (417, 13)

# %%
# Convert the 'Preterm Births (%) 2020-2022' column to numeric
df['Preterm Births (%) 2020-2022'] = pd.to_numeric(df['Preterm Births (%) 2020-2022'], errors='coerce')

# Print the rows with preterm births < 10.4
df[df['Preterm Births (%) 2020-2022'] < 10.4]
# Out:
#     County FIPS Code HRSA Region                 State                County  \
# 1              11001           3  District of Columbia  District of Columbia
# 2              34001           2            New Jersey       Atlantic County
# 3              34003           2            New Jersey         Bergen County
# 4              34005           2            New Jersey     Burlington County
# 5              34007           2            New Jersey         Camden County
# ..               ...         ...                   ...                   ...
# 333            48497           6                 Texas           Wise County
# 335            48501           6                 Texas         Yoakum County
# 336            48503           6                 Texas          Young County
# 364            72051           2           Puerto Rico      Dorado Municipio
# 365            72053           2           Puerto Rico     Fajardo Municipio
#
# ...

# %%
# Print the rows with preterm births > 10.4
df[df['Preterm Births (%) 2020-2022'] > 10.4]
# Out:
#     County FIPS Code HRSA Region        State               County  \
# 7              34011           2   New Jersey    Cumberland County
# 17             34031           2   New Jersey       Passaic County
# 25             36005           2     New York         Bronx County
# 29             36013           2     New York    Chautauqua County
# 37             36029           2     New York          Erie County
# ..               ...         ...          ...                  ...
# 411            72143           2  Puerto Rico  Vega Alta Municipio
# 413            72147           2  Puerto Rico    Vieques Municipio
# 414            72149           2  Puerto Rico   Villalba Municipio
# 415            72151           2  Puerto Rico    Yabucoa Municipio
# 416            72153           2  Puerto Rico      Yauco Municipio
#
#     Hospitals with Obstetric Care (#) OB-GYN Provider Rate (per 100,000)  \
# 7                                   1                                4.1
# ...

# %%
#can you give the average of the Preterm Births (%) 2020-2022 column
df['Preterm Births (%) 2020-2022'].mean()
# Out:
# np.float64(10.950721153846153)

# %%
#can you print the row with the highest Preterm Births (%) 2020-2022
df[df['Preterm Births (%) 2020-2022'] == df['Preterm Births (%) 2020-2022'].max()]
# Out:
#     County FIPS Code HRSA Region        State             County  \
# 415            72151           2  Puerto Rico  Yabucoa Municipio
#
#     Hospitals with Obstetric Care (#) OB-GYN Provider Rate (per 100,000)  \
# 415                                 0                                  0
#
#     Infant Mortality Rate (per 1,000) 2020-2022  \
# 415                                         6.2
#
#     Low Birth Weight (%) 2020-2022  Preterm Births (%) 2020-2022  \
# 415                           11.7                          15.4
#
#     Prenatal Care in the 1st Trimester (%) 2020-2022  \
# 415                                               81
#
#     Population Density - Women 15-44 Years of Age  \
# 415                                           NaN
#
#     NCHS Urban-Rural Classification NCHS Urban-Rural Code
# 415                             NaN                   NaN

# %%
#can you print the row with the lowest Preterm Births (%) 2020-2022
df[df['Preterm Births (%) 2020-2022'] == df['Preterm Births (%) 2020-2022'].min()]
# Out:
#    County FIPS Code HRSA Region     State        County  \
# 84            36123           2  New York  Yates County
#
#    Hospitals with Obstetric Care (#) OB-GYN Provider Rate (per 100,000)  \
# 84                                 0                                  0
#
#    Infant Mortality Rate (per 1,000) 2020-2022 Low Birth Weight (%) 2020-2022  \
# 84                                           5                            4.5
#
#     Preterm Births (%) 2020-2022  \
# 84                           6.4
#
#    Prenatal Care in the 1st Trimester (%) 2020-2022  \
# 84                                             61.5
#
#    Population Density - Women 15-44 Years of Age  \
# 84                                          11.9
#
#    NCHS Urban-Rural Classification NCHS Urban-Rural Code
# 84              Large fringe metro                     2
